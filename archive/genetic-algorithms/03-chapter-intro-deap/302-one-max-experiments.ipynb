# %% [markdown]
# # Задача OneMax. Эксперименты с параметрами алгоритма
# Проведем серию экспериментов с различными параметрами алгоритма и посмотрим на изменения в результатах.

# %%
from deap import tools
from baseline import GeneticAlgorithm

# %%
MAIN_PARAMS = {
    'seed': 42,
    'one_max_length': 100,      # длина подлежащей оптимизации битовой строки
    'population_size': 200,     # количество индивидуумов в популяции
    'p_crossover': 0.9,         # вероятность скрещивания
    'p_mutation': 0.1,          # вероятность мутации индивидуума
    'max_generation': 50,       # максимальное количество поколений
}

# %% [markdown]
# # Selection

# %% [markdown]
# ## Tournament

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournament, selection_params={"tournsize": 1})
result.run()
# Out:
# CPU times: user 305 ms, sys: 2.76 ms, total: 308 ms
# Wall time: 309 ms

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournament, selection_params={"tournsize": 2})
result.run()
# Out:
# CPU times: user 339 ms, sys: 6.54 ms, total: 346 ms
# Wall time: 365 ms

# %%
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournament, selection_params={"tournsize": 3})
result.run()

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournament, selection_params={"tournsize": 4})
result.run()
# Out:
# CPU times: user 316 ms, sys: 2.59 ms, total: 318 ms
# Wall time: 318 ms

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournament, selection_params={"tournsize": 10}, verbose=True)
result.run()
# Out:
# gen	nevals	max	avg
# 0  	200   	61 	49.695
# 1  	183   	68 	56.57
# 2  	174   	71 	62.22
# 3  	190   	75 	67.22
# 4  	170   	79 	71.36
# 5  	179   	81 	74.905
# 6  	180   	82 	78.345
# 7  	178   	87 	80.25
# 8  	181   	87 	82.29
# 9  	184   	88 	85.02
# 10 	188   	90 	86.565
# 11 	181   	90 	87.97
# 12 	177   	91 	88.87
# 13 	186   	92 	89.385
# 14 	180   	93 	90.195
# 15 	182   	93 	91.36
# 16 	178   	94 	91.88
# 17 	192   	94 	92.43
# 18 	183   	94 	92.755
# 19 	180   	94 	92.995
# 20 	188   	94 	93.06
# 21 	179   	94 	93.165
# 22 	181   	94 	93.39
# 23 	189   	94 	92.96
# 24 	179   	94 	93.015
# 25 	184   	94 	93.145
# 26 	192   	94 	92.985
# 27 	182   	94 	92.945
# 28 	181   	94 	92.97
# 29 	181   	94 	93.12
# 30 	187   	94 	93.265
# 31 	182   	94 	93.15
# 32 	181   	94 	93.07
# 33 	184   	94 	93.16
# 34 	186   	94 	93.32
# 35 	194   	94 	92.84
# 36 	180   	94 	93.345
# 37 	185   	94 	93.16
# 38 	184   	94 	92.69
# 39 	187   	94 	93.245
# 40 	188   	94 	92.815
# ...

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournament, selection_params={"tournsize": 100})
result.run()
# Out:
# CPU times: user 582 ms, sys: 5.42 ms, total: 587 ms
# Wall time: 607 ms

# %% [markdown]
# ## Roulette

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selRoulette)
result.run()
# Out:
# CPU times: user 549 ms, sys: 14.1 ms, total: 563 ms
# Wall time: 572 ms

# %%
# %%time
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selNSGA2)
result.run()
# Out:
# CPU times: user 341 ms, sys: 4.96 ms, total: 346 ms
# Wall time: 348 ms

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selSPEA2)
result.run()
# Out:
# CPU times: user 1.26 s, sys: 9.2 ms, total: 1.27 s
# Wall time: 1.28 s

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selRandom)
result.run()
# Out:
# CPU times: user 302 ms, sys: 3.28 ms, total: 305 ms
# Wall time: 305 ms

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selBest)
result.run()
# Out:
# CPU times: user 301 ms, sys: 5.68 ms, total: 307 ms
# Wall time: 307 ms

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selWorst)
result.run()
# Out:
# CPU times: user 291 ms, sys: 3.16 ms, total: 295 ms
# Wall time: 295 ms

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selTournamentDCD)
result.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/_projects_github/git-education/genetic-algorithms/03-chapter-intro-deap/baseline.py:106, in GeneticAlgorithm.run(self)
#     103 hof = tools.HallOfFame(10)
#     105 # Запуск алгоритма
# --> 106 population, logbook = algorithms.eaSimple(
#     107     population=self.population,
#     108     toolbox=self.toolbox,
#     109     cxpb=self.p_crossover,
#     110     mutpb=self.p_mutation,
#     111     ngen=self.max_generation,
#     112     stats=stats,
#     113     halloffame=hof,
#     114     verbose=self.verbose
#     115 )
#     117 # Найти первое поколение с максимальным фитнесом
#     118 self.find_first_max_generation(logbook)
#
# ...

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selDoubleTournament)
result.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/_projects_github/git-education/genetic-algorithms/03-chapter-intro-deap/baseline.py:106, in GeneticAlgorithm.run(self)
#     103 hof = tools.HallOfFame(10)
#     105 # Запуск алгоритма
# --> 106 population, logbook = algorithms.eaSimple(
#     107     population=self.population,
#     108     toolbox=self.toolbox,
#     109     cxpb=self.p_crossover,
#     110     mutpb=self.p_mutation,
#     111     ngen=self.max_generation,
#     112     stats=stats,
#     113     halloffame=hof,
#     114     verbose=self.verbose
#     115 )
#     117 # Найти первое поколение с максимальным фитнесом
#     118 self.find_first_max_generation(logbook)
#
# ...

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selStochasticUniversalSampling)
result.run()
# Out:
# CPU times: user 523 ms, sys: 4.67 ms, total: 528 ms
# Wall time: 540 ms

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selLexicase)
result.run()
# Out:
# CPU times: user 1.32 s, sys: 13.2 ms, total: 1.33 s
# Wall time: 1.36 s

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selEpsilonLexicase)
result.run()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# File ~/_projects_github/git-education/genetic-algorithms/03-chapter-intro-deap/baseline.py:106, in GeneticAlgorithm.run(self)
#     103 hof = tools.HallOfFame(10)
#     105 # Запуск алгоритма
# --> 106 population, logbook = algorithms.eaSimple(
#     107     population=self.population,
#     108     toolbox=self.toolbox,
#     109     cxpb=self.p_crossover,
#     110     mutpb=self.p_mutation,
#     111     ngen=self.max_generation,
#     112     stats=stats,
#     113     halloffame=hof,
#     114     verbose=self.verbose
#     115 )
#     117 # Найти первое поколение с максимальным фитнесом
#     118 self.find_first_max_generation(logbook)
#
# ...

# %%
# %%time  
result = GeneticAlgorithm(**MAIN_PARAMS, selection_operator=tools.selAutomaticEpsilonLexicase)
result.run()
# Out:
# CPU times: user 1.67 s, sys: 15.9 ms, total: 1.68 s
# Wall time: 1.69 s
